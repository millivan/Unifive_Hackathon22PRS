# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel("[MASA Hackathon 2022] Travel Insurance Data Set .xlsx")
df.head()
# Out:
#   Agency    Agency Type Distribution Channel                     Product Name  \
# 0    CBH  Travel Agency              Offline               Comprehensive Plan
# 1    CBH  Travel Agency              Offline               Comprehensive Plan
# 2    CWT  Travel Agency               Online  Rental Vehicle Excess Insurance
# 3    CWT  Travel Agency               Online  Rental Vehicle Excess Insurance
# 4    CWT  Travel Agency               Online  Rental Vehicle Excess Insurance
#
#   Claim  Duration Destination  Net Sales  Commision (in value) Gender  Age
# 0    No       186    MALAYSIA      -29.0                  9.57      F   81
# 1    No       186    MALAYSIA      -29.0                  9.57      F   71
# 2    No        65   AUSTRALIA      -49.5                 29.70    NaN   32
# 3    No        60   AUSTRALIA      -39.6                 23.76    NaN   32
# 4    No        79       ITALY      -19.8                 11.88    NaN   41

# %%
df.describe(include="all")
# Out:
#        Agency    Agency Type Distribution Channel       Product Name  Claim  \
# count   63326          63326                63326              63326  63326
# unique     16              2                    2                 26      2
# top       EPX  Travel Agency               Online  Cancellation Plan     No
# freq    35119          45869                62219              18630  62399
# mean      NaN            NaN                  NaN                NaN    NaN
# std       NaN            NaN                  NaN                NaN    NaN
# min       NaN            NaN                  NaN                NaN    NaN
# 25%       NaN            NaN                  NaN                NaN    NaN
# 50%       NaN            NaN                  NaN                NaN    NaN
# 75%       NaN            NaN                  NaN                NaN    NaN
# max       NaN            NaN                  NaN                NaN    NaN
#
#             Duration Destination     Net Sales  Commision (in value) Gender  \
# count   63326.000000       63326  63326.000000          63326.000000  18219
# unique           NaN         149           NaN                   NaN      2
# top              NaN   SINGAPORE           NaN                   NaN      M
# freq             NaN       13255           NaN                   NaN   9347
# mean       49.317074         NaN     40.702018              9.809992    NaN
# std       101.791566         NaN     48.845637             19.804388    NaN
# min        -2.000000         NaN   -389.000000              0.000000    NaN
# 25%         9.000000         NaN     18.000000              0.000000    NaN
# 50%        22.000000         NaN     26.530000              0.000000    NaN
# 75%        53.000000         NaN     48.000000             11.550000    NaN
# max      4881.000000         NaN    810.000000            283.500000    NaN
#
#                  Age
# count   63326.000000
# unique           NaN
# top              NaN
# freq             NaN
# mean       39.969981
# std        14.017010
# min         0.000000
# 25%        35.000000
# 50%        36.000000
# 75%        43.000000
# max       118.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 63326 entries, 0 to 63325
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Agency                63326 non-null  object
#  1   Agency Type           63326 non-null  object
#  2   Distribution Channel  63326 non-null  object
#  3   Product Name          63326 non-null  object
#  4   Claim                 63326 non-null  object
#  5   Duration              63326 non-null  int64
#  6   Destination           63326 non-null  object
#  7   Net Sales             63326 non-null  float64
#  8   Commision (in value)  63326 non-null  float64
#  9   Gender                18219 non-null  object
#  10  Age                   63326 non-null  int64
# dtypes: float64(2), int64(2), object(7)
# memory usage: 5.3+ MB

# %%
df.shape
# Out:
# (63326, 11)

# %% [markdown]
# Observations:
# 1. [Gender] has a lot of missing data.
# 2. The minimum value for [Duration] is -2, which doesn't make sense.
# 3. The minimum value for [Net Sales] is negative, which doesn't make sense too.
# 4. The maximum [Age] is 118, which is not very common.
# 5. The data has 63326 rows and 11 columns

# %%
#function to find number of outliers
def outliers(df):
    q1=df.quantile(0.25)
    q3=df.quantile(0.75)
    IQR=q3-q1
    outliers = df[((df<(q1-1.5*IQR)) | (df>(q3+1.5*IQR)))]
    return len(outliers)

# %% [markdown]
# ### [Gender]

# %% [markdown]
# Since genders has so many missing values and we couldn't find a way to fill in those null values, we will just drop that column.

# %%
df.drop(["Gender"], axis = 1, inplace = True)
df.head()
# Out:
#   Agency    Agency Type Distribution Channel                     Product Name  \
# 0    CBH  Travel Agency              Offline               Comprehensive Plan
# 1    CBH  Travel Agency              Offline               Comprehensive Plan
# 2    CWT  Travel Agency               Online  Rental Vehicle Excess Insurance
# 3    CWT  Travel Agency               Online  Rental Vehicle Excess Insurance
# 4    CWT  Travel Agency               Online  Rental Vehicle Excess Insurance
#
#   Claim  Duration Destination  Net Sales  Commision (in value)  Age
# 0    No       186    MALAYSIA      -29.0                  9.57   81
# 1    No       186    MALAYSIA      -29.0                  9.57   71
# 2    No        65   AUSTRALIA      -49.5                 29.70   32
# 3    No        60   AUSTRALIA      -39.6                 23.76   32
# 4    No        79       ITALY      -19.8                 11.88   41

# %% [markdown]
# ### [Age]

# %%
print("Number of unique values :", len(df["Age"].unique()))
print(df["Age"].value_counts(bins=10))
# Out:
# Number of unique values : 89
# (35.4, 47.2]      33341
# (23.6, 35.4]      15521
# (47.2, 59.0]       8459
# (59.0, 70.8]       2546
# (11.8, 23.6]       1780
# (106.2, 118.0]      984
# (70.8, 82.6]        588
# (82.6, 94.4]         63
# (-0.119, 11.8]       44
# (94.4, 106.2]         0
# Name: Age, dtype: int64

# %% [markdown]
# There is no one at the age from 94.4 to 106.2, but there is 984 people at the age of 106.2 to 118. We are going to remove those 984 outliers in this case.

# %%
df = df[df["Age"] < 100]
print(df["Age"].value_counts(bins=10))
# Out:
# (35.2, 44.0]     30985
# (26.4, 35.2]     13120
# (44.0, 52.8]      7189
# (52.8, 61.6]      4333
# (17.6, 26.4]      4096
# (61.6, 70.4]      1839
# (70.4, 79.2]       527
# (79.2, 88.0]       124
# (8.8, 17.6]        102
# (-0.089, 8.8]       27
# Name: Age, dtype: int64

# %% [markdown]
# ### [Duration]

# %%
df.loc[df['Duration'] <= 0]
# Out:
#       Agency    Agency Type Distribution Channel  \
# 911      RAB       Airlines               Online
# 2515     JZI       Airlines               Online
# 2868     JZI       Airlines               Online
# 3282     RAB       Airlines               Online
# 3577     SSI       Airlines               Online
# 3903     JZI       Airlines               Online
# 4281     JZI       Airlines               Online
# 6171     JZI       Airlines               Online
# 8490     SSI       Airlines               Online
# 9685     C2B       Airlines               Online
# 10550    SSI       Airlines               Online
# 11623    SSI       Airlines               Online
# 12224    SSI       Airlines               Online
# 12695    C2B       Airlines               Online
# 14119    RAB       Airlines               Online
# 16380    C2B       Airlines               Online
# 20732    SSI       Airlines               Online
# 22302    SSI       Airlines               Online
# 24934    JZI       Airlines               Online
# 27252    JZI       Airlines               Online
# 27593    CWT  Travel Agency               Online
# 28045    RAB       Airlines               Online
# 32411    CWT  Travel Agency               Online
# 35038    SSI       Airlines               Online
# 37561    LWC  Travel Agency               Online
# 38755    SSI       Airlines               Online
# 40739    SSI       Airlines               Online
# 45702    EPX  Travel Agency              Offline
# 46237    SSI       Airlines               Online
# 46894    JZI       Airlines               Online
# 48161    LWC  Travel Agency               Online
# 49873    SSI       Airlines               Online
# 55499    SSI       Airlines               Online
# 57114    RAB       Airlines               Online
# 60746    SSI       Airlines               Online
# 63097    C2B       Airlines               Online
# 63307    SSI       Airlines               Online
#
#                           Product Name Claim  Duration        Destination  \
# 911                         Value Plan    No         0  BRUNEI DARUSSALAM
# 2515                        Basic Plan    No         0            MYANMAR
# 2868                        Basic Plan    No         0          INDONESIA
# 3282                        Value Plan    No         0  BRUNEI DARUSSALAM
# 3577                  Ticket Protector    No         0          SINGAPORE
# 3903                        Basic Plan    No         0            MYANMAR
# 4281                        Basic Plan    No         0            MYANMAR
# 6171                        Basic Plan    No         0           THAILAND
# 8490                  Ticket Protector    No         0          SINGAPORE
# 9685                       Silver Plan    No         0          SINGAPORE
# 10550                 Ticket Protector    No         0          SINGAPORE
# 11623                 Ticket Protector    No         0          SINGAPORE
# 12224                 Ticket Protector    No         0          SINGAPORE
# 12695                      Bronze Plan    No         0          SINGAPORE
# 14119                       Value Plan    No         0  BRUNEI DARUSSALAM
# 16380                      Bronze Plan    No         0          SINGAPORE
# 20732                 Ticket Protector    No         0          SINGAPORE
# 22302                 Ticket Protector    No         0          SINGAPORE
# 24934                       Basic Plan    No         0           VIET NAM
# 27252                       Basic Plan    No         0              CHINA
# 27593  Rental Vehicle Excess Insurance    No         0      UNITED STATES
# 28045                       Value Plan    No         0  BRUNEI DARUSSALAM
# 32411  Rental Vehicle Excess Insurance    No         0           MALAYSIA
# 35038                 Ticket Protector    No         0          SINGAPORE
# 37561  Single Trip Travel Protect Gold    No         0           MALAYSIA
# 38755                 Ticket Protector    No         0          SINGAPORE
# 40739                 Ticket Protector    No         0          SINGAPORE
# 45702         1 way Comprehensive Plan    No         0            MYANMAR
# 46237                 Ticket Protector    No         0          SINGAPORE
# 46894                       Basic Plan    No         0              INDIA
# 48161  Single Trip Travel Protect Gold    No         0              INDIA
# 49873                 Ticket Protector    No         0          SINGAPORE
# 55499                 Ticket Protector    No         0          SINGAPORE
# 57114                       Value Plan    No         0  BRUNEI DARUSSALAM
# 60746                 Ticket Protector    No         0          SINGAPORE
# 63097                      Bronze Plan    No         0          SINGAPORE
# 63307                 Ticket Protector    No         0          SINGAPORE
#
#        Net Sales  Commision (in value)  Age
# 911        15.00                  6.00   24
# 2515       18.00                  6.30   26
# 2868       18.00                  6.30   42
# 3282       15.00                  6.00   38
# 3577       14.40                  4.04   48
# 3903       18.00                  6.30   27
# 4281       18.00                  6.30   24
# 6171       18.00                  6.30   24
# 8490        9.77                  2.74   48
# 9685        0.00                  5.63   51
# 10550       1.35                  0.38   48
# 11623       4.44                  1.25   48
# 12224       0.84                  0.24   48
# 12695      14.40                  3.60   49
# 14119      15.00                  6.00   53
# 16380     -14.40                  3.60   49
# 20732       1.80                  0.50   48
# 22302       5.80                  1.63   48
# 24934      18.00                  6.30   58
# 27252      22.00                  7.70   34
# 27593       9.90                  5.94   59
# 28045      15.00                  6.00   24
# 32411       9.90                  5.94   33
# 35038       1.03                  0.29   48
# 37561      27.00                 17.55   56
# 38755       2.86                  0.80   48
# 40739       2.44                  0.68   48
# 45702      20.00                  0.00   33
# 46237       1.93                  0.54   48
# 46894      22.00                  7.70   36
# 48161      35.25                 22.91   24
# 49873       3.99                  1.12   48
# 55499       3.34                  0.94   48
# 57114      15.00                  6.00   33
# 60746       4.88                  1.37   48
# 63097      27.00                  6.75   23
# 63307       0.51                  0.14   48

# %% [markdown]
# Some values of [Duration] are zero which does not make sense.

# %%
df_duration = df["Duration"]
df_duration.head()
# Out:
# 0    186
# 1    186
# 2     65
# 3     60
# 4     79
# Name: Duration, dtype: int64

# %%
df_duration.describe()
# Out:
# count    62342.000000
# mean        49.639136
# std        102.465902
# min          0.000000
# 25%         10.000000
# 50%         23.000000
# 75%         53.000000
# max       4881.000000
# Name: Duration, dtype: float64

# %%
print("outliers of [Duration]: ", outliers(df_duration))
# Out:
# outliers of [Duration]:  5659

# %% [markdown]
# From the results above, there are a total of 5659 outliers in the column [Duration] out of 62342. The SD is very high and the data is skewed heavily towards the right. Therefore, we are replacing the values of zero in the [Duration] column with the median.

# %%
df["Duration"] = df["Duration"].replace(0, df["Duration"].quantile(0.5))

# %%
df.describe()
# Out:
#            Duration     Net Sales  Commision (in value)           Age
# count  62342.000000  62342.000000          62342.000000  62342.000000
# mean      49.652786     40.560025              9.661998     38.738363
# std      102.460820     48.883541             19.804959     10.097333
# min        1.000000   -389.000000              0.000000      0.000000
# 25%       10.000000     18.000000              0.000000     35.000000
# 50%       23.000000     26.000000              0.000000     36.000000
# 75%       53.000000     48.000000             10.500000     43.000000
# max     4881.000000    682.000000            262.760000     88.000000

# %% [markdown]
# By looking at the first column, the minimum value of [Duration] is now 1.

# %% [markdown]
# ### [Net Sales] and [Comission]

# %% [markdown]
# Finding the relationship between these two features

# %%
df.loc[df["Commision (in value)"]<0]
# Out:
# Empty DataFrame
# Columns: [Agency, Agency Type, Distribution Channel, Product Name, Claim, Duration, Destination, Net Sales, Commision (in value), Age]
# Index: []

# %% [markdown]
# It seems that there are no negative values in [Commision]

# %%
df.loc[df['Net Sales'] < 0]
# Out:
#       Agency    Agency Type Distribution Channel  \
# 0        CBH  Travel Agency              Offline
# 1        CBH  Travel Agency              Offline
# 2        CWT  Travel Agency               Online
# 3        CWT  Travel Agency               Online
# 4        CWT  Travel Agency               Online
# ...      ...            ...                  ...
# 57991    CWT  Travel Agency               Online
# 57992    RAB       Airlines               Online
# 57993    C2B       Airlines               Online
# 57994    CWT  Travel Agency               Online
# 57995    EPX  Travel Agency               Online
#
#                           Product Name Claim  Duration        Destination  \
# 0                   Comprehensive Plan    No     186.0           MALAYSIA
# 1                   Comprehensive Plan    No     186.0           MALAYSIA
# 2      Rental Vehicle Excess Insurance    No      65.0          AUSTRALIA
# 3      Rental Vehicle Excess Insurance    No      60.0          AUSTRALIA
# 4      Rental Vehicle Excess Insurance    No      79.0              ITALY
# ...                                ...   ...       ...                ...
# 57991  Rental Vehicle Excess Insurance    No       6.0          AUSTRALIA
# 57992                       Value Plan    No       9.0  BRUNEI DARUSSALAM
# 57993               Annual Silver Plan    No     386.0          SINGAPORE
# 57994  Rental Vehicle Excess Insurance    No      28.0           MALAYSIA
# 57995                Cancellation Plan    No      29.0        NETHERLANDS
#
#        Net Sales  Commision (in value)  Age
# 0          -29.0                  9.57   81
# 1          -29.0                  9.57   71
# 2          -49.5                 29.70   32
# 3          -39.6                 23.76   32
# 4          -19.8                 11.88   41
# ...          ...                   ...  ...
# 57991       -9.9                  5.94   31
# 57992      -15.0                  6.00   46
# 57993     -161.0                 40.25   28
# 57994      -29.7                 17.82   31
# 57995      -31.0                  0.00   35
#
# [665 rows x 10 columns]

# %% [markdown]
# Several values of [Net Sales] are smaller than zero, which does not make sense.

# %%
#Calculating the percentage of comission by using the absolute value of [Net Sales]
df["Commision Percentage"] = (df["Commision (in value)"]/(df["Commision (in value)"] + abs (df["Net Sales"])))
df.head()
# Out:
#   Agency    Agency Type Distribution Channel                     Product Name  \
# 0    CBH  Travel Agency              Offline               Comprehensive Plan
# 1    CBH  Travel Agency              Offline               Comprehensive Plan
# 2    CWT  Travel Agency               Online  Rental Vehicle Excess Insurance
# 3    CWT  Travel Agency               Online  Rental Vehicle Excess Insurance
# 4    CWT  Travel Agency               Online  Rental Vehicle Excess Insurance
#
#   Claim  Duration Destination  Net Sales  Commision (in value)  Age  \
# 0    No     186.0    MALAYSIA      -29.0                  9.57   81
# 1    No     186.0    MALAYSIA      -29.0                  9.57   71
# 2    No      65.0   AUSTRALIA      -49.5                 29.70   32
# 3    No      60.0   AUSTRALIA      -39.6                 23.76   32
# 4    No      79.0       ITALY      -19.8                 11.88   41
#
#    Commision Percentage
# 0               0.24812
# 1               0.24812
# 2               0.37500
# 3               0.37500
# 4               0.37500

# %%
df.groupby("Agency")["Commision Percentage"].std()
# Out:
# Agency
# ADM    2.676453e-01
# ART    1.253861e-01
# C2B    1.035846e-01
# CBH    1.639111e-01
# CCR    1.066732e-01
# CSR    5.214365e-18
# CWT    2.000606e-01
# EPX    0.000000e+00
# JZI    1.011546e-01
# KML    3.659973e-02
# LWC    1.069366e-01
# RAB    7.466864e-02
# SSI    1.714436e-03
# TST    7.858775e-02
# TTW    0.000000e+00
# Name: Commision Percentage, dtype: float64

# %%
#df.loc[df['Agency'] == "ADM"]
#df.loc[df['Agency'] == "C2B"]
df_agency = df.loc[df['Agency'] == "CWT"]
df_agency.head(30)
# Out:
#     Agency    Agency Type Distribution Channel  \
# 2      CWT  Travel Agency               Online
# 3      CWT  Travel Agency               Online
# 4      CWT  Travel Agency               Online
# 6      CWT  Travel Agency               Online
# 7      CWT  Travel Agency               Online
# 8      CWT  Travel Agency               Online
# 9      CWT  Travel Agency               Online
# 13     CWT  Travel Agency               Online
# 15     CWT  Travel Agency               Online
# 16     CWT  Travel Agency               Online
# 17     CWT  Travel Agency               Online
# 19     CWT  Travel Agency               Online
# 20     CWT  Travel Agency               Online
# 26     CWT  Travel Agency               Online
# 27     CWT  Travel Agency               Online
# 28     CWT  Travel Agency               Online
# 29     CWT  Travel Agency               Online
# 30     CWT  Travel Agency               Online
# 31     CWT  Travel Agency               Online
# 32     CWT  Travel Agency               Online
# 127    CWT  Travel Agency               Online
# 128    CWT  Travel Agency               Online
# 129    CWT  Travel Agency               Online
# 130    CWT  Travel Agency               Online
# 131    CWT  Travel Agency               Online
# 132    CWT  Travel Agency               Online
# 133    CWT  Travel Agency               Online
# 134    CWT  Travel Agency               Online
# 135    CWT  Travel Agency               Online
# 136    CWT  Travel Agency               Online
#
#                         Product Name Claim  Duration     Destination  \
# 2    Rental Vehicle Excess Insurance    No      65.0       AUSTRALIA
# 3    Rental Vehicle Excess Insurance    No      60.0       AUSTRALIA
# 4    Rental Vehicle Excess Insurance    No      79.0           ITALY
# 6    Rental Vehicle Excess Insurance    No      47.0   UNITED STATES
# 7    Rental Vehicle Excess Insurance    No      63.0       AUSTRALIA
# 8    Rental Vehicle Excess Insurance    No      57.0        THAILAND
# 9    Rental Vehicle Excess Insurance    No     186.0       AUSTRALIA
# 13   Rental Vehicle Excess Insurance    No       5.0        MALAYSIA
# 15   Rental Vehicle Excess Insurance    No       6.0         DENMARK
# 16   Rental Vehicle Excess Insurance    No      48.0         DENMARK
# 17   Rental Vehicle Excess Insurance    No      11.0   UNITED STATES
# 19   Rental Vehicle Excess Insurance    No      14.0        THAILAND
# 20   Rental Vehicle Excess Insurance    No     136.0          NORWAY
# 26   Rental Vehicle Excess Insurance    No      29.0   UNITED STATES
# 27   Rental Vehicle Excess Insurance    No      28.0   UNITED STATES
# 28   Rental Vehicle Excess Insurance    No     153.0           JAPAN
# 29   Rental Vehicle Excess Insurance    No      28.0  UNITED KINGDOM
# 30   Rental Vehicle Excess Insurance    No       4.0  UNITED KINGDOM
# 31   Rental Vehicle Excess Insurance    No      54.0       AUSTRALIA
# 32   Rental Vehicle Excess Insurance    No      24.0       AUSTRALIA
# 127  Rental Vehicle Excess Insurance    No      23.0        MALAYSIA
# 128  Rental Vehicle Excess Insurance    No      29.0       AUSTRALIA
# 129  Rental Vehicle Excess Insurance    No       5.0        MALAYSIA
# 130  Rental Vehicle Excess Insurance    No      26.0   UNITED STATES
# 131  Rental Vehicle Excess Insurance    No      26.0        THAILAND
# 132  Rental Vehicle Excess Insurance    No     152.0   UNITED STATES
# 133  Rental Vehicle Excess Insurance    No      48.0       AUSTRALIA
# 134  Rental Vehicle Excess Insurance    No       5.0        MALAYSIA
# 135  Rental Vehicle Excess Insurance    No      30.0        MALAYSIA
# 136  Rental Vehicle Excess Insurance    No       9.0        THAILAND
#
#      Net Sales  Commision (in value)  Age  Commision Percentage
# 2        -49.5                 29.70   32                 0.375
# 3        -39.6                 23.76   32                 0.375
# 4        -19.8                 11.88   41                 0.375
# 6        -39.6                 23.76   32                 0.375
# 7       -108.9                 65.34   29                 0.375
# 8        -19.8                 11.88   44                 0.375
# 9        -99.0                 59.40   37                 0.375
# 13       -39.6                 23.76   64                 0.375
# 15       -19.8                 11.88   53                 0.375
# 16       -79.2                 47.52   43                 0.375
# 17       -29.7                 17.82   58                 0.375
# 19       -69.3                 41.58   37                 0.375
# 20      -108.9                 65.34   32                 0.375
# 26         9.9                  5.94   33                 0.375
# 27         9.9                  5.94   33                 0.375
# 28        69.3                 41.58   35                 0.375
# 29        19.8                 11.88   31                 0.375
# 30        29.7                 17.82   61                 0.375
# 31         0.0                 41.58   31                 1.000
# 32        89.1                 53.46   33                 0.375
# 127       29.7                 17.82   31                 0.375
# 128       39.6                 23.76   52                 0.375
# 129        0.0                 29.70   53                 1.000
# 130      148.5                 89.10   40                 0.375
# 131       29.7                 17.82   31                 0.375
# 132        9.9                  5.94   31                 0.375
# 133       59.4                 35.64   26                 0.375
# 134       39.6                 23.76   60                 0.375
# 135       59.4                 35.64   27                 0.375
# 136       49.5                 29.70   50                 0.375

# %% [markdown]
# The above shows that the [Commision Percentage] are the same within the same [Agency] if we use the absolute value of [Net Sales] to calculate the result. Moreover, from index 13 and 128, we can see that the absolute value of both [Net Sales] are the same. This induces that the negative value could be a typing error. Therefore, we are going to replace all the [Net Sales] with its absolute value.

# %%
df["Net Sales"] = df["Net Sales"].apply(lambda x : abs(x))
df_agency = df.loc[df['Agency'] == "CWT"]
df_agency.head(30)
# Out:
#     Agency    Agency Type Distribution Channel  \
# 2      CWT  Travel Agency               Online
# 3      CWT  Travel Agency               Online
# 4      CWT  Travel Agency               Online
# 6      CWT  Travel Agency               Online
# 7      CWT  Travel Agency               Online
# 8      CWT  Travel Agency               Online
# 9      CWT  Travel Agency               Online
# 13     CWT  Travel Agency               Online
# 15     CWT  Travel Agency               Online
# 16     CWT  Travel Agency               Online
# 17     CWT  Travel Agency               Online
# 19     CWT  Travel Agency               Online
# 20     CWT  Travel Agency               Online
# 26     CWT  Travel Agency               Online
# 27     CWT  Travel Agency               Online
# 28     CWT  Travel Agency               Online
# 29     CWT  Travel Agency               Online
# 30     CWT  Travel Agency               Online
# 31     CWT  Travel Agency               Online
# 32     CWT  Travel Agency               Online
# 127    CWT  Travel Agency               Online
# 128    CWT  Travel Agency               Online
# 129    CWT  Travel Agency               Online
# 130    CWT  Travel Agency               Online
# 131    CWT  Travel Agency               Online
# 132    CWT  Travel Agency               Online
# 133    CWT  Travel Agency               Online
# 134    CWT  Travel Agency               Online
# 135    CWT  Travel Agency               Online
# 136    CWT  Travel Agency               Online
#
#                         Product Name Claim  Duration     Destination  \
# 2    Rental Vehicle Excess Insurance    No      65.0       AUSTRALIA
# 3    Rental Vehicle Excess Insurance    No      60.0       AUSTRALIA
# 4    Rental Vehicle Excess Insurance    No      79.0           ITALY
# 6    Rental Vehicle Excess Insurance    No      47.0   UNITED STATES
# 7    Rental Vehicle Excess Insurance    No      63.0       AUSTRALIA
# 8    Rental Vehicle Excess Insurance    No      57.0        THAILAND
# 9    Rental Vehicle Excess Insurance    No     186.0       AUSTRALIA
# 13   Rental Vehicle Excess Insurance    No       5.0        MALAYSIA
# 15   Rental Vehicle Excess Insurance    No       6.0         DENMARK
# 16   Rental Vehicle Excess Insurance    No      48.0         DENMARK
# 17   Rental Vehicle Excess Insurance    No      11.0   UNITED STATES
# 19   Rental Vehicle Excess Insurance    No      14.0        THAILAND
# 20   Rental Vehicle Excess Insurance    No     136.0          NORWAY
# 26   Rental Vehicle Excess Insurance    No      29.0   UNITED STATES
# 27   Rental Vehicle Excess Insurance    No      28.0   UNITED STATES
# 28   Rental Vehicle Excess Insurance    No     153.0           JAPAN
# 29   Rental Vehicle Excess Insurance    No      28.0  UNITED KINGDOM
# 30   Rental Vehicle Excess Insurance    No       4.0  UNITED KINGDOM
# 31   Rental Vehicle Excess Insurance    No      54.0       AUSTRALIA
# 32   Rental Vehicle Excess Insurance    No      24.0       AUSTRALIA
# 127  Rental Vehicle Excess Insurance    No      23.0        MALAYSIA
# 128  Rental Vehicle Excess Insurance    No      29.0       AUSTRALIA
# 129  Rental Vehicle Excess Insurance    No       5.0        MALAYSIA
# 130  Rental Vehicle Excess Insurance    No      26.0   UNITED STATES
# 131  Rental Vehicle Excess Insurance    No      26.0        THAILAND
# 132  Rental Vehicle Excess Insurance    No     152.0   UNITED STATES
# 133  Rental Vehicle Excess Insurance    No      48.0       AUSTRALIA
# 134  Rental Vehicle Excess Insurance    No       5.0        MALAYSIA
# 135  Rental Vehicle Excess Insurance    No      30.0        MALAYSIA
# 136  Rental Vehicle Excess Insurance    No       9.0        THAILAND
#
#      Net Sales  Commision (in value)  Age  Commision Percentage
# 2         49.5                 29.70   32                 0.375
# 3         39.6                 23.76   32                 0.375
# 4         19.8                 11.88   41                 0.375
# 6         39.6                 23.76   32                 0.375
# 7        108.9                 65.34   29                 0.375
# 8         19.8                 11.88   44                 0.375
# 9         99.0                 59.40   37                 0.375
# 13        39.6                 23.76   64                 0.375
# 15        19.8                 11.88   53                 0.375
# 16        79.2                 47.52   43                 0.375
# 17        29.7                 17.82   58                 0.375
# 19        69.3                 41.58   37                 0.375
# 20       108.9                 65.34   32                 0.375
# 26         9.9                  5.94   33                 0.375
# 27         9.9                  5.94   33                 0.375
# 28        69.3                 41.58   35                 0.375
# 29        19.8                 11.88   31                 0.375
# 30        29.7                 17.82   61                 0.375
# 31         0.0                 41.58   31                 1.000
# 32        89.1                 53.46   33                 0.375
# 127       29.7                 17.82   31                 0.375
# 128       39.6                 23.76   52                 0.375
# 129        0.0                 29.70   53                 1.000
# 130      148.5                 89.10   40                 0.375
# 131       29.7                 17.82   31                 0.375
# 132        9.9                  5.94   31                 0.375
# 133       59.4                 35.64   26                 0.375
# 134       39.6                 23.76   60                 0.375
# 135       59.4                 35.64   27                 0.375
# 136       49.5                 29.70   50                 0.375

# %% [markdown]
# We also spotted a few 0 values in [Net Sales] with their commision not equal to 0. Let's take a look at these special cases.

# %%
df.loc[df["Net Sales"] == 0]
# Out:
#       Agency    Agency Type Distribution Channel  \
# 31       CWT  Travel Agency               Online
# 80       EPX  Travel Agency               Online
# 87       EPX  Travel Agency               Online
# 129      CWT  Travel Agency               Online
# 144      CWT  Travel Agency               Online
# ...      ...            ...                  ...
# 62806    C2B       Airlines               Online
# 62833    CWT  Travel Agency               Online
# 62993    CWT  Travel Agency               Online
# 62996    CWT  Travel Agency               Online
# 63001    CWT  Travel Agency               Online
#
#                           Product Name Claim  Duration         Destination  \
# 31     Rental Vehicle Excess Insurance    No      54.0           AUSTRALIA
# 80                   Cancellation Plan    No      38.0  KOREA, REPUBLIC OF
# 87                   Cancellation Plan    No       8.0            VIET NAM
# 129    Rental Vehicle Excess Insurance    No       5.0            MALAYSIA
# 144    Rental Vehicle Excess Insurance    No     201.0           AUSTRALIA
# ...                                ...   ...       ...                 ...
# 62806                      Bronze Plan    No      12.0           SINGAPORE
# 62833  Rental Vehicle Excess Insurance    No     165.0           AUSTRALIA
# 62993  Rental Vehicle Excess Insurance    No       5.0            MALAYSIA
# 62996  Rental Vehicle Excess Insurance    No       3.0            MALAYSIA
# 63001  Rental Vehicle Excess Insurance    No      13.0            MALAYSIA
#
#        Net Sales  Commision (in value)  Age  Commision Percentage
# 31           0.0                 41.58   31                   1.0
# 80           0.0                  0.00   36                   NaN
# 87           0.0                  0.00   36                   NaN
# 129          0.0                 29.70   53                   1.0
# 144          0.0                 77.22   23                   1.0
# ...          ...                   ...  ...                   ...
# 62806        0.0                  6.63   24                   1.0
# 62833        0.0                 29.70   26                   1.0
# 62993        0.0                 17.82   53                   1.0
# 62996        0.0                 17.82   49                   1.0
# 63001        0.0                 11.88   62                   1.0
#
# [1866 rows x 11 columns]

# %% [markdown]
# There are 1866 rows that has 0 [Net Sales]. Let's replace them by reverse calculation, using [Net Sales] = [Comission] / [Comission Percentage] - [Commision]

# %%
#Finding the mode [Commision Percentage] of every [Agency]
percentage_commision = df.groupby("Agency")["Commision Percentage"].agg(pd.Series.mode)
percentage_commision
# Out:
# Agency
# ADM                                      0.275362
# ART                                      0.259259
# C2B                                           0.2
# CBH                                       0.24812
# CCR                                       0.24812
# CSR                                       0.24812
# CWT                                         0.375
# EPX                                           0.0
# JZI                                      0.259259
# KML                                      0.275362
# LWC                                      0.393939
# RAB                                      0.285714
# SSI    [0.21965317919075145, 0.21969696969696967]
# TST                                      0.259259
# TTW                                           0.0
# Name: Commision Percentage, dtype: object

# %%
percentage_commision.loc["SSI"] = percentage_commision.loc["SSI"][0]

# %%
percentage_commision = pd.core.frame.DataFrame(percentage_commision)
percentage_commision = percentage_commision.reset_index()
percentage_commision.head()
# Out:
#   Agency Commision Percentage
# 0    ADM             0.275362
# 1    ART             0.259259
# 2    C2B                  0.2
# 3    CBH              0.24812
# 4    CCR              0.24812

# %%
#Dropping the initial [Commision Percentage] and replacing it with the mode of the initial [Commision Percentage] 
#of different Agency
df.drop(["Commision Percentage"], axis=1, inplace = True)
df = df.merge(percentage_commision[["Agency", "Commision Percentage"]], 'left')
df.head()
# Out:
#   Agency    Agency Type Distribution Channel                     Product Name  \
# 0    CBH  Travel Agency              Offline               Comprehensive Plan
# 1    CBH  Travel Agency              Offline               Comprehensive Plan
# 2    CWT  Travel Agency               Online  Rental Vehicle Excess Insurance
# 3    CWT  Travel Agency               Online  Rental Vehicle Excess Insurance
# 4    CWT  Travel Agency               Online  Rental Vehicle Excess Insurance
#
#   Claim  Duration Destination  Net Sales  Commision (in value)  Age  \
# 0    No     186.0    MALAYSIA       29.0                  9.57   81
# 1    No     186.0    MALAYSIA       29.0                  9.57   71
# 2    No      65.0   AUSTRALIA       49.5                 29.70   32
# 3    No      60.0   AUSTRALIA       39.6                 23.76   32
# 4    No      79.0       ITALY       19.8                 11.88   41
#
#   Commision Percentage
# 0              0.24812
# 1              0.24812
# 2                0.375
# 3                0.375
# 4                0.375

# %%
for i in range(df.shape[0]):
    if (df.loc[i, "Agency"] != "EPX") and (df.loc[i, "Agency"] != "TTW"):
        df.loc[i, "Net Sales"] = df.loc[i, "Commision (in value)"] / df.loc[i, "Commision Percentage"] - df.loc[i, "Commision (in value)"]
    else:
        continue
df.head()
# Out:
#   Agency    Agency Type Distribution Channel                     Product Name  \
# 0    CBH  Travel Agency              Offline               Comprehensive Plan
# 1    CBH  Travel Agency              Offline               Comprehensive Plan
# 2    CWT  Travel Agency               Online  Rental Vehicle Excess Insurance
# 3    CWT  Travel Agency               Online  Rental Vehicle Excess Insurance
# 4    CWT  Travel Agency               Online  Rental Vehicle Excess Insurance
#
#   Claim  Duration Destination  Net Sales  Commision (in value)  Age  \
# 0    No     186.0    MALAYSIA       29.0                  9.57   81
# 1    No     186.0    MALAYSIA       29.0                  9.57   71
# 2    No      65.0   AUSTRALIA       49.5                 29.70   32
# 3    No      60.0   AUSTRALIA       39.6                 23.76   32
# 4    No      79.0       ITALY       19.8                 11.88   41
#
#   Commision Percentage
# 0              0.24812
# 1              0.24812
# 2                0.375
# 3                0.375
# 4                0.375

# %%
#Changing the columns' position
df = df[["Agency", "Agency Type", "Distribution Channel", "Product Name", "Claim", "Duration", "Destination", 
         "Age", "Net Sales", "Commision (in value)", "Commision Percentage"]]
df.head()
# Out:
#   Agency    Agency Type Distribution Channel                     Product Name  \
# 0    CBH  Travel Agency              Offline               Comprehensive Plan
# 1    CBH  Travel Agency              Offline               Comprehensive Plan
# 2    CWT  Travel Agency               Online  Rental Vehicle Excess Insurance
# 3    CWT  Travel Agency               Online  Rental Vehicle Excess Insurance
# 4    CWT  Travel Agency               Online  Rental Vehicle Excess Insurance
#
#   Claim  Duration Destination  Age  Net Sales  Commision (in value)  \
# 0    No     186.0    MALAYSIA   81       29.0                  9.57
# 1    No     186.0    MALAYSIA   71       29.0                  9.57
# 2    No      65.0   AUSTRALIA   32       49.5                 29.70
# 3    No      60.0   AUSTRALIA   32       39.6                 23.76
# 4    No      79.0       ITALY   41       19.8                 11.88
#
#   Commision Percentage
# 0              0.24812
# 1              0.24812
# 2                0.375
# 3                0.375
# 4                0.375

# %%
df.shape
# Out:
# (62342, 11)

# %% [markdown]
# After data cleaning, we are left with 62342 rows of data

# %%
# exporting the cleaned data into an excel file
df.to_excel("[MASA Hackathon 2022] Travel Insurance Data Set (Cleaned).xlsx", index = False);
